# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from random import randint, seed

import env

# %%
# 2. Create and label 4 separate charts with the following equations (choose a range for x that makes sense):

# %%
x = np.array(range(0,10))
y = x ** 0.5

plt.plot(x,y);

# %%
x = np.array(range(-10,10))
y = x ** 3

plt.plot(x,y);

# %%
x = np.array(range(0,10))
y = 2 ** x

plt.plot(x,y);

# %%
x = np.array(range(-10,10))
# print(x)
y = 1 / (x+1)

plt.plot(x,y);
# Out:
# /var/folders/00/7kh6hl_d42xgcrdm5cz1m3t40000gn/T/ipykernel_955/2208089974.py:3: RuntimeWarning: divide by zero encountered in divide
#   y = 1 / (x+1)

# %%
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.
plt.figure(figsize=(12,6))
plt.subplot(1,4,1) #subplot(#ofrows, #ofcolumns,#position of plot)

x = np.array(range(0,11))
y = x**0.5
plt.plot(x,y)

plt.subplot(1,4,2)
x = np.array(range(-10,11))
y = x**3
plt.plot(x,y)

plt.subplot(143)
x = np.array(range(0,11))
y = 2**x
plt.plot(x,y)

plt.subplot(144)
x = np.array(range(-10,10))
y = 1 / (x+1)
plt.plot(x,y)

# plt.title('test title')
plt.suptitle('four subplots') #title for subplots
plt.tight_layout() #ensures i can see my axises
plt.show()
# Out:
# /var/folders/00/7kh6hl_d42xgcrdm5cz1m3t40000gn/T/ipykernel_955/2881803997.py:21: RuntimeWarning: divide by zero encountered in divide
#   y = 1 / (x+1)
